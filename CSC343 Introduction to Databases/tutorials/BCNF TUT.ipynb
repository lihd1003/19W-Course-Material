# %% [markdown]
# 1. (a) Create an instance of relation $R(A,B,C,D,E)$ that violates FD $ABC\rightarrow DE$
# <table>
#         <tr>
#                 <th>A</th><th>B</th><th>C</th><th>D</th><th>E</th>
#         </tr>
#         <tr>
#                 <td>1</td><td>1</td><td>1</td><td>2</td><td>2</td>
#         </tr>
#         <tr>
#                 <td>1</td><td>1</td><td>1</td><td>2</td><td>3</td>
#         </tr>
# </table>
# (b) Given the instance below, does FD $DB\rightarrow A$ holds
# <table>
#         <tr>
#                 <th>A</th><th>B</th><th>C</th><th>D</th><th>E</th>
#         </tr>
#         <tr>
#                 <td>5</td><td>3</td><td>2</td><td>1</td><td>6</td>
#         </tr>
#         <tr>
#                 <td>5</td><td>3</td><td>3</td><td>1</td><td>2</td>
#         </tr>
#         <tr>
#                 <td>5</td><td>8</td><td>4</td><td>1</td><td>5</td>
#         </tr>
# </table>
# YES

# %% [markdown]
# 2. Is a relation in BCNF?
#
# Students(sID, email, course, term, prof)
# $sID\rightarrow email, course$
# $term\rightarrow prof$
# $sID, course \rightarrow grade$
# NO, consider $sID^+=sID, email$ , $sID$ in not a superkey
#
# Customer(name, DOB, address, fCar, manufacturer)
# $name\rightarrow DOB, fCar$   $fCar\rightarrow manufacturer$
# NO, consider $name^+ = name, DOB$ is not a superkey.
#
# Parts(part, manufacturer, seller, price)
# $part\rightarrow manufacturer$
# $part, seller\rightarrow price$
#
# NO, consider $part^+ = part, manufacturer$ is not a superkey
#
# R(A,B,C,D,E)
# $B\rightarrow AC$
# $CB\rightarrow E$
# $A\rightarrow D$
#
# NO, consider $B^+= ABC$ is not a superkey

# %% [markdown]
# 3. Parts(part, manufacturer, seller, price)
# $part\rightarrow manufacturer$
# $part, seller\rightarrow price$
#
# make an instance having redundant info
# <table>
#         <tr>
#                 <th>part</th><th>manufacturer</th><th>seller</th><th>price</th>
#         </tr>
#         <tr>
#                 <td>p1</td><td>m1</td><td>s1</td><td>1</td>
#         </tr>
#         <tr>
#                 <td>p1</td><td>m1</td><td>s2</td><td>2</td><td></td>
#         </tr>
# </table>
#
# If we apply the decomposition, what attributes would each of the new relations have?
# - R1(part, manufacturer)
# - R2(part, seller, price)
#
# Project FD onto each of the new relationship
# - R1: $part\rightarrow manufacturer$
# - R2: $part, seller\rightarrow price$
#
# Put the same data into new relationship
# <table>
#         <tr>
#                 <th>part</th><th>manufacturer</th>
#         </tr>
#         <tr>
#                 <td>p1</td><td>m1</td>
#         </tr>
# </table>
#
# <table>
#         <tr>
#                 <th>part</th><th>seller</th><th>price</th>
#         </tr>
#         <tr>
#                 <td>p1</td><td>s1</td><td>1</td>
#         </tr>
#         <tr>
#                 <td>p1</td><td>s2</td><td>2</td>
#         </tr>
# </table>
#
# Is it possible to create redundancy?
# NO, don't have further decomposition
