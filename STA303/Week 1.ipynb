# %% [markdown]
# ### Case Study: Spock Conspiracy Trail

# %%
# import data
library(Sleuth2)
percent = case0502$Percent
judge = case0502$Judge

# %%
plot(judge, percent)
# Out:
# plot without title

# %%
summary(percent)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    6.40   19.95   27.50   26.58   32.38   48.90

# %%
boxplot(percent, horizontal = T)
# Out:
# plot without title

# %%
t.test(percent, mu = 50)
# Out:
# 	One Sample t-test
#
# data:  percent
# t = -17.303, df = 45, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 50
# 95 percent confidence interval:
#  23.85675 29.30847
# sample estimates:
# mean of x
#  26.58261

# %% [markdown]
# **One sample two sided test** <br>
# hypothesis: $H_0:\mu=50$ <br>
# test statistic: $\frac{\bar{X}-\mu_0}{S/\sqrt{n}}\sim T_{n-1}$ <br>
# The result is significant, we can reject the hypothesis.

# %%
par(mfrow = c(1,2))
hist(percent)
qqnorm(percent)
qqline(percent)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
shapiro.test(percent)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  percent
# W = 0.98763, p-value = 0.9013

# %%
boxplot(percent[judge == "Spock's"], percent[judge != 'SPOCK'], names = c("Spock", "Other"))
# Out:
# plot without title
