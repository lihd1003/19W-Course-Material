# %% [markdown]
# Suppose we have the following relation instance
# <table>
#         <tr>
#                 <th>cdf</th><th>name</th><th>grade</th>
#         </tr>
#         <tr>
#                 <td>g3</td><td>Amy</td><td>91</td>
#         </tr>
#         <tr>
#                 <td>g4</td><td>David</td><td>78</td>
#         </tr>
#         <tr>
#                 <td>c0</td><td>David</td><td>85</td>
#         </tr>
# </table>
#
# Decompose into R1(cdf, name) and R2(name, grade). Project the data onto the new relations
# <table>
#         <tr>
#                 <th>cdf</th><th>name</th>
#         </tr>
#         <tr>
#                 <td>g3</td><td>Amy</td>
#         </tr>
#         <tr>
#                 <td>g4</td><td>David</td>
#         </tr>
#         <tr>
#                 <td>c0</td><td>David</td>
#         </tr>
# </table>
# <table>
#         <tr>
#                 <th>name</th><th>grade</th>
#         </tr>
#         <tr>
#                 <td>Amy</td><td>91</td>
#         </tr>
#         <tr>
#                 <td>David</td><td>78</td>
#         </tr>
#         <tr>
#                 <td>David</td><td>85</td>
#         </tr>
# </table>
#
# Compute $R_1\bowtie R_2$
# <table>
#         <tr>
#                 <th>cdf</th><th>name</th><th>grade</th>
#         </tr>
#         <tr>
#                 <td>g3</td><td>Amy</td><td>91</td>
#         </tr>
#         <tr>
#                 <td>g4</td><td>David</td><td>78</td>
#         </tr>
#         <tr>
#                 <td>g4</td><td>David</td><td>85</td>
#         </tr>
#     <tr>
#                 <td>c0</td><td>David</td><td>78</td>
#         </tr>
#         <tr>
#                 <td>c0</td><td>David</td><td>85</td>
#         </tr>
#
# </table>

# %% [markdown]
# R(movie, theater, city)
# $theater\rightarrow city$
# $movie, city \rightarrow theater$
#
# BCNF decomposition result:
# R1(theater, city) with $theater\rightarrow city$
# R2(theater, movie)
#
# Create instances that violates dependency preservation
# <table>
#         <tr>
#                 <th>theater</th><th>city</th>
#         </tr>
#         <tr>
#                 <td>1</td><td>1</td>
#         </tr>
#         <tr>
#                 <td>2</td><td>1</td>
#         </tr>
# </table>
# <table>
#         <tr>
#                 <th>theater</th><th>movie</th>
#         </tr>
#         <tr>
#                 <td>1</td><td>1</td>
#         </tr>
#         <tr>
#                 <td>2</td><td>1</td>
#         </tr>
# </table>
# <table>
#         <tr>
#                 <th>theater</th><th>city</th><th>movie</th>
#         </tr>
#         <tr>
#                 <td>1</td><td>1</td><td>1</td>
#         </tr>
#         <tr>
#                 <td>2</td><td>1</td><td>1</td>
#         </tr>
# </table>
#
# Does $theater\rightarrow city$ in $R$ violates 3NF or BCNF?
# theater is not a superkey but city is prime (part of the superkey). It NOT violates 3NF, violates BCNF.
