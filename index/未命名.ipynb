# %%
import os
ss = []
for i in os.walk("../"):
    for j in i[2]:
        if ".ipynb" in j and "-chechpoint" not in j:
            path = i[0] + "/" + j
            if "table_of_content" not in path:
                ss.append(path)

# %%
for f in ss:
    ! jupyter nbconvert --to=html --template=github.tpl "$f"
# Out:
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/Final Review.ipynb to html
# [NbConvertApp] Writing 16600 bytes to ../MAT337 Introduction to Real Analysis/Final Review.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/Test Questions.ipynb to html
# [NbConvertApp] Writing 6890 bytes to ../MAT337 Introduction to Real Analysis/Test Questions.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/1. Real Number Construction.ipynb to html
# [NbConvertApp] Writing 10258 bytes to ../MAT337 Introduction to Real Analysis/NOTE/1. Real Number Construction.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/2. Extremum.ipynb to html
# [NbConvertApp] Writing 7665 bytes to ../MAT337 Introduction to Real Analysis/NOTE/2. Extremum.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/9. Arzela-Ascoli Theorem.ipynb to html
# [NbConvertApp] Writing 14470 bytes to ../MAT337 Introduction to Real Analysis/NOTE/9. Arzela-Ascoli Theorem.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/Extra. Stone Weierstrass Theorem.ipynb to html
# [NbConvertApp] Writing 6533 bytes to ../MAT337 Introduction to Real Analysis/NOTE/Extra. Stone Weierstrass Theorem.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/6. Inner Product Space and Fourier Series.ipynb to html
# [NbConvertApp] Writing 15173 bytes to ../MAT337 Introduction to Real Analysis/NOTE/6. Inner Product Space and Fourier Series.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/8. Series.ipynb to html
# [NbConvertApp] Writing 16135 bytes to ../MAT337 Introduction to Real Analysis/NOTE/8. Series.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/4. Topology of real number space.ipynb to html
# [NbConvertApp] Writing 18409 bytes to ../MAT337 Introduction to Real Analysis/NOTE/4. Topology of real number space.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/10. Function Approximations.ipynb to html
# [NbConvertApp] Writing 9444 bytes to ../MAT337 Introduction to Real Analysis/NOTE/10. Function Approximations.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/3. MCT and BWT.ipynb to html
# [NbConvertApp] Writing 9121 bytes to ../MAT337 Introduction to Real Analysis/NOTE/3. MCT and BWT.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/7. Convergence of Functions.ipynb to html
# [NbConvertApp] Writing 16636 bytes to ../MAT337 Introduction to Real Analysis/NOTE/7. Convergence of Functions.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/11. Fixed Point and ODE.ipynb to html
# [NbConvertApp] Writing 11427 bytes to ../MAT337 Introduction to Real Analysis/NOTE/11. Fixed Point and ODE.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/NOTE/5. Normed Space.ipynb to html
# [NbConvertApp] Writing 10373 bytes to ../MAT337 Introduction to Real Analysis/NOTE/5. Normed Space.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT4.ipynb to html
# [NbConvertApp] Writing 5699 bytes to ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT4.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT5.ipynb to html
# [NbConvertApp] Writing 7180 bytes to ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT5.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT10.ipynb to html
# [NbConvertApp] Writing 7076 bytes to ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT10.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT9.ipynb to html
# [NbConvertApp] Writing 5612 bytes to ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT9.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/TUTORIAL/REVIEW QUESTIONS.ipynb to html
# [NbConvertApp] Writing 7694 bytes to ../MAT337 Introduction to Real Analysis/TUTORIAL/REVIEW QUESTIONS.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT2.ipynb to html
# [NbConvertApp] Writing 6557 bytes to ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT2.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT6.ipynb to html
# [NbConvertApp] Writing 5637 bytes to ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT6.html
# [NbConvertApp] Converting notebook ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT3.ipynb to html
# [NbConvertApp] Writing 5776 bytes to ../MAT337 Introduction to Real Analysis/TUTORIAL/TUT3.html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/Summary.ipynb to html
# [NbConvertApp] Writing 17832 bytes to ../STA303 Methods of Data Analysis II/Summary.html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/Two Way ANOVA/Two Way ANOVA.ipynb to html
# [NbConvertApp] Writing 120389 bytes to ../STA303 Methods of Data Analysis II/Two Way ANOVA/Two Way ANOVA.html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/Poisson Regression/Practice Problems.ipynb to html
# [NbConvertApp] Writing 12713 bytes to ../STA303 Methods of Data Analysis II/Poisson Regression/Practice Problems.html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/Poisson Regression/Log-linear Regression (Poisson Regression).ipynb to html
# [NbConvertApp] Writing 85144 bytes to ../STA303 Methods of Data Analysis II/Poisson Regression/Log-linear Regression (Poisson Regression).html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/One Way ANOVA/One Way ANOVA.ipynb to html
# [NbConvertApp] Writing 65080 bytes to ../STA303 Methods of Data Analysis II/One Way ANOVA/One Way ANOVA.html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/One Way ANOVA/Introduction.ipynb to html
# [NbConvertApp] Writing 93048 bytes to ../STA303 Methods of Data Analysis II/One Way ANOVA/Introduction.html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/One Way ANOVA/Multi Comparisons.ipynb to html
# [NbConvertApp] Writing 28474 bytes to ../STA303 Methods of Data Analysis II/One Way ANOVA/Multi Comparisons.html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/Binary Logistic Regression/Binary Logistic Regression.ipynb to html
# [NbConvertApp] Writing 98898 bytes to ../STA303 Methods of Data Analysis II/Binary Logistic Regression/Binary Logistic Regression.html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/Contingency tables/Factor independence.ipynb to html
# [NbConvertApp] Writing 19902 bytes to ../STA303 Methods of Data Analysis II/Contingency tables/Factor independence.html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/Contingency tables/Three-way Contingency .ipynb to html
# [NbConvertApp] Writing 38456 bytes to ../STA303 Methods of Data Analysis II/Contingency tables/Three-way Contingency .html
# [NbConvertApp] Converting notebook ../STA303 Methods of Data Analysis II/Binomial Logistic Regression/Binomial Logistic Regression.ipynb to html
# [NbConvertApp] Writing 78926 bytes to ../STA303 Methods of Data Analysis II/Binomial Logistic Regression/Binomial Logistic Regression.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/TUTORIAL/SQL queries TUT.ipynb to html
# [NbConvertApp] Writing 25661 bytes to ../CSC343 Introduction to Databases/TUTORIAL/SQL queries TUT.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/TUTORIAL/Relational Algebra TUT.ipynb to html
# [NbConvertApp] Writing 13830 bytes to ../CSC343 Introduction to Databases/TUTORIAL/Relational Algebra TUT.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/TUTORIAL/Properties of Decompositions TUT.ipynb to html
# [NbConvertApp] Writing 7351 bytes to ../CSC343 Introduction to Databases/TUTORIAL/Properties of Decompositions TUT.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/TUTORIAL/Projection and Minimal Basis TUT.ipynb to html
# [NbConvertApp] Writing 5359 bytes to ../CSC343 Introduction to Databases/TUTORIAL/Projection and Minimal Basis TUT.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/TUTORIAL/The Chase Test.ipynb to html
# [NbConvertApp] Writing 7378 bytes to ../CSC343 Introduction to Databases/TUTORIAL/The Chase Test.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/TUTORIAL/BCNF TUT.ipynb to html
# [NbConvertApp] Writing 7757 bytes to ../CSC343 Introduction to Databases/TUTORIAL/BCNF TUT.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/TUTORIAL/Functional Dependencies TUT.ipynb to html
# [NbConvertApp] Writing 8045 bytes to ../CSC343 Introduction to Databases/TUTORIAL/Functional Dependencies TUT.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/NOTES/SQL Data Definition.ipynb to html
# [NbConvertApp] Writing 23498 bytes to ../CSC343 Introduction to Databases/NOTES/SQL Data Definition.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/NOTES/SQL queries.ipynb to html
# [NbConvertApp] Writing 24162 bytes to ../CSC343 Introduction to Databases/NOTES/SQL queries.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/NOTES/Relational Model.ipynb to html
# [NbConvertApp] Writing 7639 bytes to ../CSC343 Introduction to Databases/NOTES/Relational Model.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/NOTES/SQL Schema.ipynb to html
# [NbConvertApp] Writing 5397 bytes to ../CSC343 Introduction to Databases/NOTES/SQL Schema.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/NOTES/Functional dependency.ipynb to html
# [NbConvertApp] Writing 18770 bytes to ../CSC343 Introduction to Databases/NOTES/Functional dependency.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/NOTES/SQL data manipulation.ipynb to html
# [NbConvertApp] Writing 11949 bytes to ../CSC343 Introduction to Databases/NOTES/SQL data manipulation.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/NOTES/Relational Algebra.ipynb to html
# [NbConvertApp] Writing 13119 bytes to ../CSC343 Introduction to Databases/NOTES/Relational Algebra.html
# [NbConvertApp] Converting notebook ../CSC343 Introduction to Databases/NOTES/Embedding SQL to another language.ipynb to html
# [NbConvertApp] Writing 4597 bytes to ../CSC343 Introduction to Databases/NOTES/Embedding SQL to another language.html
# [NbConvertApp] Converting notebook ../STA302 Methods of Data Analysis I/Lecture code - Intro R.ipynb to html
# [NbConvertApp] Writing 79375 bytes to ../STA302 Methods of Data Analysis I/Lecture code - Intro R.html
# [NbConvertApp] Converting notebook ../STA302 Methods of Data Analysis I/R basics.ipynb to html
# [NbConvertApp] Writing 44114 bytes to ../STA302 Methods of Data Analysis I/R basics.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/Gradient Descent.ipynb to html
# [NbConvertApp] Writing 7785 bytes to ../CSC311 Intro to Machine Learning/NOTE/Gradient Descent.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/Classification Optimization.ipynb to html
# [NbConvertApp] Writing 47118 bytes to ../CSC311 Intro to Machine Learning/NOTE/Classification Optimization.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/Neural Networks.ipynb to html
# [NbConvertApp] Writing 35254 bytes to ../CSC311 Intro to Machine Learning/NOTE/Neural Networks.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/PCA.ipynb to html
# [NbConvertApp] Writing 7360 bytes to ../CSC311 Intro to Machine Learning/NOTE/PCA.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/Bias-Variane Decomposition.ipynb to html
# [NbConvertApp] Writing 12825 bytes to ../CSC311 Intro to Machine Learning/NOTE/Bias-Variane Decomposition.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/Decision Trees.ipynb to html
# [NbConvertApp] Writing 34148 bytes to ../CSC311 Intro to Machine Learning/NOTE/Decision Trees.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/k-Nearest Neighbors.ipynb to html
# [NbConvertApp] Writing 122798 bytes to ../CSC311 Intro to Machine Learning/NOTE/k-Nearest Neighbors.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/Linear Regression.ipynb to html
# [NbConvertApp] Writing 10305 bytes to ../CSC311 Intro to Machine Learning/NOTE/Linear Regression.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/SVM and Boosting.ipynb to html
# [NbConvertApp] Writing 81515 bytes to ../CSC311 Intro to Machine Learning/NOTE/SVM and Boosting.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/.ipynb_checkpoints/Neural Networks-checkpoint.ipynb to html
# [NbConvertApp] Writing 35276 bytes to ../CSC311 Intro to Machine Learning/NOTE/.ipynb_checkpoints/Neural Networks-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/.ipynb_checkpoints/Gradient Descent-checkpoint.ipynb to html
# [NbConvertApp] Writing 7807 bytes to ../CSC311 Intro to Machine Learning/NOTE/.ipynb_checkpoints/Gradient Descent-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/.ipynb_checkpoints/Bias-Variane Decomposition-checkpoint.ipynb to html
# [NbConvertApp] Writing 12847 bytes to ../CSC311 Intro to Machine Learning/NOTE/.ipynb_checkpoints/Bias-Variane Decomposition-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/.ipynb_checkpoints/Linear Classification & Optimization-checkpoint.ipynb to html
# [NbConvertApp] Writing 43808 bytes to ../CSC311 Intro to Machine Learning/NOTE/.ipynb_checkpoints/Linear Classification & Optimization-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/NOTE/.ipynb_checkpoints/Linear Regression-checkpoint.ipynb to html
# [NbConvertApp] Writing 10327 bytes to ../CSC311 Intro to Machine Learning/NOTE/.ipynb_checkpoints/Linear Regression-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/TUTORIAL/CSC311_Fall_2019_Tutorial3_worksheet.ipynb to html
# [NbConvertApp] Writing 508441 bytes to ../CSC311 Intro to Machine Learning/TUTORIAL/CSC311_Fall_2019_Tutorial3_worksheet.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/TUTORIAL/CSC311_Fall_2019_Tutorial3_lecture.ipynb to html
# [NbConvertApp] Writing 1268702 bytes to ../CSC311 Intro to Machine Learning/TUTORIAL/CSC311_Fall_2019_Tutorial3_lecture.html
# [NbConvertApp] Converting notebook ../CSC311 Intro to Machine Learning/TUTORIAL/plot_bias_variance.ipynb to html
# [NbConvertApp] Writing 155817 bytes to ../CSC311 Intro to Machine Learning/TUTORIAL/plot_bias_variance.html
# [NbConvertApp] Converting notebook ../CSC336 Numerical Methods/Computer Arithmetic.ipynb to html
# [NbConvertApp] Writing 15216 bytes to ../CSC336 Numerical Methods/Computer Arithmetic.html
# [NbConvertApp] Converting notebook ../CSC336 Numerical Methods/Untitled.ipynb to html
# [NbConvertApp] Writing 4462 bytes to ../CSC336 Numerical Methods/Untitled.html
# [NbConvertApp] Converting notebook ../CSC336 Numerical Methods/LU Decomposition.ipynb to html
# [NbConvertApp] Writing 86665 bytes to ../CSC336 Numerical Methods/LU Decomposition.html
# [NbConvertApp] Converting notebook ../CSC336 Numerical Methods/Pivoting.ipynb to html
# [NbConvertApp] Writing 13591 bytes to ../CSC336 Numerical Methods/Pivoting.html
# [NbConvertApp] Converting notebook ../CSC336 Numerical Methods/Norms of vectors and matrices.ipynb to html
# [NbConvertApp] Writing 7778 bytes to ../CSC336 Numerical Methods/Norms of vectors and matrices.html
# [NbConvertApp] Converting notebook ../CSC336 Numerical Methods/Approxmation Errors and Conditioning, Stability.ipynb to html
# [NbConvertApp] Writing 52546 bytes to ../CSC336 Numerical Methods/Approxmation Errors and Conditioning, Stability.html
# [NbConvertApp] Converting notebook ../CSC336 Numerical Methods/Computer Arithmetic Examples.ipynb to html
# [NbConvertApp] Writing 52752 bytes to ../CSC336 Numerical Methods/Computer Arithmetic Examples.html
# [NbConvertApp] Converting notebook ../CSC336 Numerical Methods/Conditioning of Linear Equation Systems.ipynb to html
# [NbConvertApp] Writing 11275 bytes to ../CSC336 Numerical Methods/Conditioning of Linear Equation Systems.html
# [NbConvertApp] Converting notebook ../CSC336 Numerical Methods/.ipynb_checkpoints/Norms of vectors and matrices-checkpoint.ipynb to html
# [NbConvertApp] Writing 7571 bytes to ../CSC336 Numerical Methods/.ipynb_checkpoints/Norms of vectors and matrices-checkpoint.html
# [NbConvertApp] Converting notebook ../STA457 Time Series Analysis/0-NOTES/ARMA.ipynb to html
# [NbConvertApp] Writing 18422 bytes to ../STA457 Time Series Analysis/0-NOTES/ARMA.html
# [NbConvertApp] Converting notebook ../STA457 Time Series Analysis/0-NOTES/Applications of ARMA models in investments.ipynb to html
# [NbConvertApp] Writing 6390 bytes to ../STA457 Time Series Analysis/0-NOTES/Applications of ARMA models in investments.html
# [NbConvertApp] Converting notebook ../STA457 Time Series Analysis/0-NOTES/Granger Causality and Cointegration.ipynb to html
# [NbConvertApp] Writing 8055 bytes to ../STA457 Time Series Analysis/0-NOTES/Granger Causality and Cointegration.html
# [NbConvertApp] Converting notebook ../STA457 Time Series Analysis/0-NOTES/TFN model.ipynb to html
# [NbConvertApp] Writing 11145 bytes to ../STA457 Time Series Analysis/0-NOTES/TFN model.html
# [NbConvertApp] Converting notebook ../STA457 Time Series Analysis/0-NOTES/ARIMA.ipynb to html
# [NbConvertApp] Writing 7497 bytes to ../STA457 Time Series Analysis/0-NOTES/ARIMA.html
# [NbConvertApp] Converting notebook ../STA457 Time Series Analysis/0-NOTES/Final Review Questions.ipynb to html
# [NbConvertApp] Writing 19178 bytes to ../STA457 Time Series Analysis/0-NOTES/Final Review Questions.html
# [NbConvertApp] Converting notebook ../STA457 Time Series Analysis/0-NOTES/Introduction.ipynb to html
# [NbConvertApp] Writing 9526 bytes to ../STA457 Time Series Analysis/0-NOTES/Introduction.html
# [NbConvertApp] Converting notebook ../STA457 Time Series Analysis/0-NOTES/Midterm Review Questions.ipynb to html
# [NbConvertApp] Writing 15210 bytes to ../STA457 Time Series Analysis/0-NOTES/Midterm Review Questions.html
# [NbConvertApp] Converting notebook ../STA457 Time Series Analysis/0-NOTES/Forecasting.ipynb to html
# [NbConvertApp] Writing 7099 bytes to ../STA457 Time Series Analysis/0-NOTES/Forecasting.html
# [NbConvertApp] Converting notebook ../STA457 Time Series Analysis/0-NOTES/Vector Series.ipynb to html
# [NbConvertApp] Writing 7628 bytes to ../STA457 Time Series Analysis/0-NOTES/Vector Series.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/Image Features - Blob Detection.ipynb to html
# [NbConvertApp] Writing 184719 bytes to ../CSC420 Intro to Image Understanding/NOTE/Image Features - Blob Detection.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/Edge Detection.ipynb to html
# [NbConvertApp] Writing 864443 bytes to ../CSC420 Intro to Image Understanding/NOTE/Edge Detection.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/Linear Filters.ipynb to html
# [NbConvertApp] Writing 2229002 bytes to ../CSC420 Intro to Image Understanding/NOTE/Linear Filters.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/Scale Invariant Feature Transform.ipynb to html
# [NbConvertApp] Writing 693401 bytes to ../CSC420 Intro to Image Understanding/NOTE/Scale Invariant Feature Transform.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/Image Pyramids.ipynb to html
# [NbConvertApp] Writing 682803 bytes to ../CSC420 Intro to Image Understanding/NOTE/Image Pyramids.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/Homography and Camera.ipynb to html
# [NbConvertApp] Writing 76373 bytes to ../CSC420 Intro to Image Understanding/NOTE/Homography and Camera.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/Image Features - Harris Corner Detector.ipynb to html
# [NbConvertApp] Writing 133605 bytes to ../CSC420 Intro to Image Understanding/NOTE/Image Features - Harris Corner Detector.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Image Pyramids-checkpoint.ipynb to html
# [NbConvertApp] Writing 681511 bytes to ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Image Pyramids-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Image Features - Interest Point Detection-checkpoint.ipynb to html
# [NbConvertApp] Writing 5635 bytes to ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Image Features - Interest Point Detection-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Homography and Camera-checkpoint.ipynb to html
# [NbConvertApp] Writing 76395 bytes to ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Homography and Camera-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Edge Detection-checkpoint.ipynb to html
# [NbConvertApp] Writing 864793 bytes to ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Edge Detection-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Scale Invariant Feature Transform-checkpoint.ipynb to html
# [NbConvertApp] Writing 693423 bytes to ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Scale Invariant Feature Transform-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Image Features - Blob Detection-checkpoint.ipynb to html
# [NbConvertApp] Writing 184741 bytes to ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Image Features - Blob Detection-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Linear Filters-checkpoint.ipynb to html
# [NbConvertApp] Writing 2229188 bytes to ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Linear Filters-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Image Features - Harris Corner Detector-checkpoint.ipynb to html
# [NbConvertApp] Writing 133627 bytes to ../CSC420 Intro to Image Understanding/NOTE/.ipynb_checkpoints/Image Features - Harris Corner Detector-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/TUTORIAL/CSC420_Deep_Learning_Tutorial_Oct_21.ipynb to html
# [NbConvertApp] Writing 90593 bytes to ../CSC420 Intro to Image Understanding/TUTORIAL/CSC420_Deep_Learning_Tutorial_Oct_21.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/TUTORIAL/CSC420_2019_Tutorial_A.ipynb to html
# [NbConvertApp] Writing 3137374 bytes to ../CSC420 Intro to Image Understanding/TUTORIAL/CSC420_2019_Tutorial_A.html
# [NbConvertApp] Converting notebook ../CSC420 Intro to Image Understanding/TUTORIAL/CSC420_2019_Tutorial_B.ipynb to html
# [NbConvertApp] Writing 290994 bytes to ../CSC420 Intro to Image Understanding/TUTORIAL/CSC420_2019_Tutorial_B.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class1/Class1-Part2.ipynb to html
# [NbConvertApp] Writing 19332 bytes to ../JSC270 Data Science I/class1/Class1-Part2.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class1/Week 1.ipynb to html
# [NbConvertApp] Writing 34152 bytes to ../JSC270 Data Science I/class1/Week 1.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class1/Class1-EDA_OkCupid.ipynb to html
# [NbConvertApp] Writing 182403 bytes to ../JSC270 Data Science I/class1/Class1-EDA_OkCupid.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class1/Class1.ipynb to html
# [NbConvertApp] Writing 91466 bytes to ../JSC270 Data Science I/class1/Class1.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/TUTORIAL/jsc270_tut3_student.ipynb to html
# [NbConvertApp] Writing 37070 bytes to ../JSC270 Data Science I/TUTORIAL/jsc270_tut3_student.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/TUTORIAL/jsc270_tut2_student.ipynb to html
# [NbConvertApp] Writing 25732 bytes to ../JSC270 Data Science I/TUTORIAL/jsc270_tut2_student.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/TUTORIAL/jsc270_tut1_questions.ipynb to html
# [NbConvertApp] Writing 40945 bytes to ../JSC270 Data Science I/TUTORIAL/jsc270_tut1_questions.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/TUTORIAL/jsc270_tut4_part2_questions.ipynb to html
# [NbConvertApp] Writing 16521 bytes to ../JSC270 Data Science I/TUTORIAL/jsc270_tut4_part2_questions.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/TUTORIAL/tut_answer/jsc270_tut1_answers_moon_99999999.ipynb to html
# [NbConvertApp] Writing 267260 bytes to ../JSC270 Data Science I/TUTORIAL/tut_answer/jsc270_tut1_answers_moon_99999999.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/TUTORIAL/tut_answer/jsc270_tut4_part2-answers-moon-99999999.ipynb to html
# [NbConvertApp] Writing 101096 bytes to ../JSC270 Data Science I/TUTORIAL/tut_answer/jsc270_tut4_part2-answers-moon-99999999.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/TUTORIAL/tut_answer/jsc270_tut2-answers_moon_999999999.ipynb to html
# [NbConvertApp] Writing 451895 bytes to ../JSC270 Data Science I/TUTORIAL/tut_answer/jsc270_tut2-answers_moon_999999999.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/package examples/big query.ipynb to html
# [NbConvertApp] Writing 29368 bytes to ../JSC270 Data Science I/package examples/big query.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/package examples/language processing.ipynb to html
# [NbConvertApp] Writing 11000 bytes to ../JSC270 Data Science I/package examples/language processing.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/package examples/plotly map plots.ipynb to html
# [NbConvertApp] Writing 28017 bytes to ../JSC270 Data Science I/package examples/plotly map plots.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class7/visualization theory and principles.ipynb to html
# [NbConvertApp] Writing 5670 bytes to ../JSC270 Data Science I/class7/visualization theory and principles.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class6/lecture6_v1.ipynb to html
# [NbConvertApp] Writing 356700 bytes to ../JSC270 Data Science I/class6/lecture6_v1.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class6/Tut4.ipynb to html
# [NbConvertApp] Writing 4362 bytes to ../JSC270 Data Science I/class6/Tut4.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class5/lecture5_ver1.ipynb to html
# [NbConvertApp] Writing 185313 bytes to ../JSC270 Data Science I/class5/lecture5_ver1.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class3/lecture3_slides-students.ipynb to html
# [NbConvertApp] Writing 495417 bytes to ../JSC270 Data Science I/class3/lecture3_slides-students.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class4/jsc270_lecture4.ipynb to html
# [NbConvertApp] Writing 209219 bytes to ../JSC270 Data Science I/class4/jsc270_lecture4.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class8/Pitfalls in Data Science.ipynb to html
# [NbConvertApp] Writing 5602 bytes to ../JSC270 Data Science I/class8/Pitfalls in Data Science.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class2/lecture2_slides-posted.ipynb to html
# [NbConvertApp] Writing 327037 bytes to ../JSC270 Data Science I/class2/lecture2_slides-posted.html
# [NbConvertApp] Converting notebook ../JSC270 Data Science I/class2/lecture2_slides_posted2.ipynb to html
# [NbConvertApp] Writing 336306 bytes to ../JSC270 Data Science I/class2/lecture2_slides_posted2.html
# [NbConvertApp] Converting notebook ../CSC320 Intro to Visual Computing/.ipynb_checkpoints/The Camera-checkpoint.ipynb to html
# [NbConvertApp] Writing 11070 bytes to ../CSC320 Intro to Visual Computing/.ipynb_checkpoints/The Camera-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC320 Intro to Visual Computing/NOTE/High Dynamic Range.ipynb to html
# [NbConvertApp] Writing 10239 bytes to ../CSC320 Intro to Visual Computing/NOTE/High Dynamic Range.html
# [NbConvertApp] Converting notebook ../CSC320 Intro to Visual Computing/NOTE/Polynomial Fitting.ipynb to html
# [NbConvertApp] Writing 28287 bytes to ../CSC320 Intro to Visual Computing/NOTE/Polynomial Fitting.html
# [NbConvertApp] Converting notebook ../CSC320 Intro to Visual Computing/NOTE/The Camera.ipynb to html
# [NbConvertApp] Writing 14701 bytes to ../CSC320 Intro to Visual Computing/NOTE/The Camera.html
# [NbConvertApp] Converting notebook ../CSC320 Intro to Visual Computing/NOTE/Image Matting.ipynb to html
# [NbConvertApp] Writing 8740 bytes to ../CSC320 Intro to Visual Computing/NOTE/Image Matting.html
# [NbConvertApp] Converting notebook ../CSC320 Intro to Visual Computing/NOTE/.ipynb_checkpoints/Polynomial Fitting-checkpoint.ipynb to html
# [NbConvertApp] Writing 7857 bytes to ../CSC320 Intro to Visual Computing/NOTE/.ipynb_checkpoints/Polynomial Fitting-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC320 Intro to Visual Computing/TUTORIAL/opencv_demo_week1_2.ipynb to html
# [NbConvertApp] Writing 962886 bytes to ../CSC320 Intro to Visual Computing/TUTORIAL/opencv_demo_week1_2.html
# [NbConvertApp] Converting notebook ../CSC320 Intro to Visual Computing/TUTORIAL/Solving Overdetermined Equations.ipynb to html
# [NbConvertApp] Writing 5871 bytes to ../CSC320 Intro to Visual Computing/TUTORIAL/Solving Overdetermined Equations.html
# [NbConvertApp] Converting notebook ../CSC320 Intro to Visual Computing/TUTORIAL/numpy_demo_week1.ipynb to html
# [NbConvertApp] Writing 35184 bytes to ../CSC320 Intro to Visual Computing/TUTORIAL/numpy_demo_week1.html
# [NbConvertApp] Converting notebook ../CSC320 Intro to Visual Computing/TUTORIAL/.ipynb_checkpoints/opencv_demo_week1_2-checkpoint.ipynb to html
# [NbConvertApp] Writing 962908 bytes to ../CSC320 Intro to Visual Computing/TUTORIAL/.ipynb_checkpoints/opencv_demo_week1_2-checkpoint.html
# [NbConvertApp] Converting notebook ../CSC309 Programming on the Web/html&css/HTML&CSS.ipynb to html
# [NbConvertApp] Writing 5325 bytes to ../CSC309 Programming on the Web/html&css/HTML&CSS.html
# [NbConvertApp] Converting notebook ../CSC309 Programming on the Web/javascript/JavaScript.ipynb to html
# [NbConvertApp] Writing 15739 bytes to ../CSC309 Programming on the Web/javascript/JavaScript.html
# [NbConvertApp] Converting notebook ../CSC309 Programming on the Web/DOM/DOM.ipynb to html
# [NbConvertApp] Writing 6719 bytes to ../CSC309 Programming on the Web/DOM/DOM.html
# [NbConvertApp] Converting notebook ../index/未命名.ipynb to html
# [NbConvertApp] Writing 23576 bytes to ../index/未命名.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Greedy Algorithm.ipynb to html
# [NbConvertApp] Writing 23384 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Greedy Algorithm.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Linear Programming.ipynb to html
# [NbConvertApp] Writing 9477 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Linear Programming.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Dynamic Programming.ipynb to html
# [NbConvertApp] Writing 37933 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Dynamic Programming.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Optimization Approxiamation.ipynb to html
# [NbConvertApp] Writing 13649 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Optimization Approxiamation.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/P_NP problem.ipynb to html
# [NbConvertApp] Writing 14503 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/P_NP problem.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/NP-complete Tut.ipynb to html
# [NbConvertApp] Writing 7748 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/NP-complete Tut.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Self Reducibility.ipynb to html
# [NbConvertApp] Writing 11823 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Self Reducibility.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Linear Programming Tut.ipynb to html
# [NbConvertApp] Writing 7324 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Linear Programming Tut.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/P_NP problem Tut.ipynb to html
# [NbConvertApp] Writing 6057 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/P_NP problem Tut.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Greedy Algorithm Tut.ipynb to html
# [NbConvertApp] Writing 10655 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Greedy Algorithm Tut.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Network Flow.ipynb to html
# [NbConvertApp] Writing 14308 bytes to ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Network Flow.html
# [NbConvertApp] Converting notebook ../CSC373 Algorithm Design, Analysis and Complexity/NOTE/Dynamic Programming Tut.ipynb to html

# %%
from bs4 import BeautifulSoup
import os, time
LINK_HTML = '<li class="breadcrumb-item"><a href="{link}">{name}</a></li>'

ENTRY_HTML = """
<div class="col-lg-4 ol-md-6 mb-2">
          <a href="{link}" class="text-dark">
          <div class="boxed p-2 scaling">
            <div class="row align-items-center justify-content-between">
              <div class="col-10">
                <div class="media align-items-center">
                  <h4><i class="icon-{icon} mr-2"></i></h4>
                  <div class="media-body">
                    <h6 class="mb-0">{name}</h6>
                    <span class="text-muted">{mtime}</span>
                  </div>
                </div>
              </div>
            </div>
          </div>
        </a>
        </div>
"""

EXCLUDE = ['ipynb', 'assets', 'index', '.tpl', '.git', 'README.md']

# %%
def format_entry(i):
    for exc in EXCLUDE:
        if exc in i:
            return None
        
    _, fext = os.path.splitext(i)
    icon = "code"
    type_ = "Regular File"

    mtime = os.path.getmtime(i)
    mtime = time.strftime("%X %x", time.localtime(mtime))
    link = "./" + os.path.basename(i)

    if os.path.isdir(i):
        icon = "folder"
        type_ = "Folder"
        link += "/index.html"
    elif fext.lower() == ".html":
        icon = "book"
        type_ = "Notebook"
    elif fext.lower() == ".pdf":
        icon = "file-text"
        type_ = "PDF File"

    return ENTRY_HTML.format(link=link, icon=icon, 
                             name=os.path.basename(i), mtime=mtime)

# %%
def create_index(dir_path, template):
    
    
    html = open(template).read()
    soup = BeautifulSoup(html)
    path = soup.find(id="path")
    dentry = soup.find(id="dentry")
    abspath = os.path.abspath(dir_path)
    absp = []
    abspath, curr = os.path.split(abspath)
    while curr != "":
        absp.append(curr)
        abspath, curr = os.path.split(abspath)
    absp.reverse()
    absindex = absp.index('UofT-Course-Material-Repo')
    
    if absindex != -1 and len(absp[absindex:]) >= 2:
        end = absindex + 2
        while end <= len(absp):
            link = "/" + "/".join(absp[absindex: end]) + "/index.html"
            name = absp[end-1]
            insert_string = LINK_HTML.format(link=link, name=name)
            insert_soup = BeautifulSoup(insert_string, 'html.parser')
            path.append(insert_soup)
            end += 1

    files = os.listdir(dir_path)
    files.sort()
    for i in files:
        insert_string = format_entry(dir_path + i)
        if insert_string:
            insert_soup = BeautifulSoup(insert_string, 'html.parser')
            dentry.append(insert_soup)
            
    return soup

# %%
folder_set = set([i[0] for i in os.walk("../")])
all_folder = []
for i in folder_set:
    inc = True
    for exc in EXCLUDE:
        if exc in i:
            inc = False
            break
    if inc:
        all_folder.append(i+ "/")
        
        
for i in all_folder:
    index = create_index(i, "./template.html")
    with open(i + "/index.html", "w") as f:
        f.write(str(index))
