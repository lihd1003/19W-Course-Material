# %% [markdown]
# R(N,F,L,C,G)
# $N\rightarrow F,L$
# $N,C\rightarrow G$
#
# 1. suppose we decompose into NF, FLC, LCG. perform chase test
#
# Step 1
# <table>
#         <tr>
#                 <th>N</th><th>F</th><th>L</th><th>C</th><th>G</th>
#         </tr>
#         <tr>
#                 <td>n</td><td>f</td><td>-</td><td>-</td><td>-</td>
#         </tr>
#         <tr>
#                 <td>-</td><td>f</td><td>l</td><td>c</td><td>-</td>
#         </tr>
#         <tr>
#                 <td>-</td><td>-</td><td>l</td><td>c</td><td>g</td>
#         </tr>
# </table>
#
# Step 2
# $N\rightarrow FL$ no problem
# $NL\rightarrow Q$ no problem
#
# Therefore, lossy.

# %% [markdown]
# 2. NF, NL, NCG
#
# Step 1
# <table>
#         <tr>
#                 <th>N</th><th>F</th><th>L</th><th>C</th><th>G</th>
#         </tr>
#         <tr>
#                 <td>n</td><td>f</td><td>-</td><td>-</td><td>-</td>
#         </tr>
#         <tr>
#                 <td>n</td><td>-</td><td>l</td><td>-</td><td>-</td>
#         </tr>
#         <tr>
#                 <td>n</td><td>-</td><td>-</td><td>c</td><td>g</td>
#         </tr>
# </table>
#
# Step 2
# $N\rightarrow FL$ =>
# <table>
#         <tr>
#                 <th>N</th><th>F</th><th>L</th><th>C</th><th>G</th>
#         </tr>
#         <tr>
#                 <td>n</td><td>f</td><td>l</td><td>-</td><td>-</td>
#         </tr>
#         <tr>
#                 <td>n</td><td>f</td><td>l</td><td>-</td><td>-</td>
#         </tr>
#         <tr>
#                 <td>n</td><td>f</td><td>l</td><td>c</td><td>g</td>
#         </tr>
# </table>
# Therefore, lossless.

# %% [markdown]
# 3. NFC, NLG
#
# Step 1
# <table>
#         <tr>
#                 <th>N</th><th>F</th><th>L</th><th>C</th><th>G</th>
#         </tr>
#         <tr>
#                 <td>n</td><td>f</td><td>-</td><td>c</td><td>-</td>
#         </tr>
#         <tr>
#                 <td>n</td><td>-</td><td>l</td><td>-</td><td>g</td>
#         </tr>
# </table>
#
# Step 2
# $N\rightarrow FL$ =>
# <table>
#         <tr>
#                 <th>N</th><th>F</th><th>L</th><th>C</th><th>G</th>
#         </tr>
#         <tr>
#                 <td>n</td><td>f</td><td>l</td><td>c</td><td>-</td>
#         </tr>
#         <tr>
#                 <td>n</td><td>f</td><td>l</td><td>-</td><td>g</td>
#         </tr>
# </table>
# $NC\rightarrow G$=>
# <table>
#         <tr>
#                 <th>N</th><th>F</th><th>L</th><th>C</th><th>G</th>
#         </tr>
#         <tr>
#                 <td>n</td><td>f</td><td>l</td><td>c</td><td>g</td>
#         </tr>
#         <tr>
#                 <td>n</td><td>f</td><td>l</td><td>c</td><td>g</td>
#         </tr>
# </table>
#
# Therefore, lossless
